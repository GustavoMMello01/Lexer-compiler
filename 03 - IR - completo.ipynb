# %%
import re
import math

T_KEYWORD = "keyword"
T_OP = "op"
T_INT = "int"
T_FLOAT = "float"
T_STRING = "string"
T_ID = "id"
T_EOF = "eof"
T_DELIMITER = "delimiter"
T_BLOCK = "block"
T_PARA = "parenthesis"
T_VAR_TYPE = "var_type"
T_IF = "if"
T_ELIF = "elif"
T_ELSE = "else"
T_OP_COMP = 'T_OP_COMP' 
T_PRINT = "print"
T_WHILE = 'while'
T_FOR = 'for'
T_ARROW_UP = "arrow_up"  
T_ARROW_DOWN = "arrow_down"
T_COMMA = "comma"
T_FUNC = "func"
T_RETURN = "return"
T_MAIN = "main"

class Token():
    
    def __init__(self, tipo, valor=None):
        self.tipo = tipo
        self.valor = valor
        
    def __str__(self):
        return '<%s %s>' % (self.tipo, self.valor)
    
    def __repr__(self):
        return self.__str__()


class StopExecution(Exception):
    def _render_traceback_(self):
        pass

    
def afd_int(token):
    try:
        int_pattern = r'^-?\d+$'
        if re.match(int_pattern, str(token)):
            return True
        return False
    except:
        return False

def afd_float(token):
    try:
        float_pattern = r'^-?\d+\.\d+$'  
        if re.match(float_pattern, str(token)):
            return True
        return False
    except:
        return False
    
def afd_string(token):
    if token[0] == '"' and token[-1] == '"':
        if '"' not in token[1:-1]:
            return True
        else:
            raise ValueError('Aspas em um local inesperado.')
    else:
        return False
    
def afd_identificador(token):
    regex = re.compile('[a-zA-Z0-9_]+')
    r = regex.match(token)
    if r is not None:
        if r.group() == token:
            return True
        else:
            return False
    else:
        return False

def afd_return(token):
    return token == "return"
    
def afd_print(token):
    return token == "print"
    
def afd_if(token):
    return token == "if"

def afd_elif(token):
    return token == "elif"

def afd_else(token):
    return token == "else"

def afd_delimiter(token):
    return token == ";"

def afd_block(token):
    return token in ["{", "}"]

def afd_var_type(token):
    return token in ["var"]

def afd_para(token):
    return token in ["(", ")"]
    
def afd_principal(token):
    if token == "main":
        return Token(T_MAIN, 'main')
    
    elif token in "=+-*/^":
        return Token(T_OP, token)
    
    elif token in ["==", "!=", "<", ">", "<=", ">="]:
        return Token(T_OP_COMP, token)

    if token == "func":
        return Token(T_FUNC, token)

    elif afd_return(token):
        return Token(T_RETURN, token)

    elif afd_int(token):
        return Token(T_INT, token)
    
    elif afd_float(token):
        return Token(T_FLOAT, token)
    
    elif afd_string(token):
        return Token(T_STRING, token)
    
    elif afd_if(token):
        return Token(T_IF, token)
    
    elif afd_elif(token):
        return Token(T_ELIF, token)
    
    elif afd_else(token):
        return Token(T_ELSE, token)
    
    if token == 'while':
        return Token(T_WHILE, token)
    
    elif token == 'for':
        return Token(T_FOR, token)

    elif token == "->":
        return Token(T_ARROW_UP, token)
    elif token == "<-":
        return Token(T_ARROW_DOWN, token)
    
    elif token == ",":
        return Token(T_COMMA, token)
    
    elif afd_print(token):
        return Token(T_PRINT, token)
    
    elif afd_delimiter(token):
        return Token(T_DELIMITER, token)
    
    elif afd_block(token):
        return Token(T_BLOCK, token)
    
    elif afd_var_type(token):
        return Token(T_VAR_TYPE, token)
    
    elif afd_para(token):
        return Token(T_PARA, token)
    
    elif afd_identificador(token):
        return Token(T_ID, token)
    
    else:
        raise ValueError('Valor inesperado')

class Parser():
    
    def __init__(self, tokens):
        self.tokens = tokens
        self.pos = -1
        self.token_atual = None
        self.symbol_table = {}
        self.ir = []
        self.scopes = [{}]  # Inicia com um escopo global
        
        self.proximo()

    def enter_scope(self):
        """ Entrar em um novo escopo. """
        self.scopes.append({})

    def exit_scope(self):
        """ Sair do escopo atual. """
        self.scopes.pop()

    def add_to_symbol_table(self, name):
        """ Adicionar variável ao escopo atual. """
        if name in self.scopes[-1]:
            raise Exception(f"Erro semantico. Variável {name} foi declarada mais de uma vez neste escopo.")
        self.scopes[-1][name] = None
    
    def is_declared_in_scope(self, name):
        """ Verificar se a variável foi declarada em algum escopo. """
        return any(name in scope for scope in reversed(self.scopes))

    def generate_ir(self):
        return "\n".join(self.ir)
        
    def proximo(self):
        self.pos += 1
        
        if self.pos >= len(self.tokens):
            self.token_atual = Token(T_EOF)
        else:    
            self.token_atual = self.tokens[self.pos]

        print(self.token_atual)

        print(f"Token atual: {self.token_atual}, Posição: {self.pos}") 
        return self.token_atual
    
    
    def erro(self, expected=None, message=None):
        error_message = f'Erro de sintaxe. Esperado: {expected}, Encontrado: {self.token_atual}'
        if message:
            error_message += f" {message}"
        raise Exception(error_message)
        
        
    def use(self, tipo, valor=None):
        if self.token_atual.tipo != tipo or (valor is not None and self.token_atual.valor != valor):
            self.erro(expected=f"{tipo}{' ' + valor if valor else ''}")
        else:
            self.proximo()
    
    def instructions(self):
        """
        statements ::= <instruction> <instructions>
        """
        print("Parsing instructions...") 
        while self.token_atual.tipo in [T_VAR_TYPE, T_ID, T_IF, T_ELIF, T_ELSE, T_PRINT, T_WHILE, T_FOR]:
            self.instruction()
            if self.token_atual.tipo == T_BLOCK and self.token_atual.valor == "}":
                break
            
    
    def instruction(self):
        """
        instruction ::= int <id> | float <id>;
        instruction ::= statement ;
        """
        print("Parsing instruction...") 
        if self.token_atual.tipo == T_VAR_TYPE:
            self.variable_declaration()
        elif self.token_atual.tipo == T_ID:
            # Verifica se é uma atribuição ou chamada de função
            next_token = self.peek()
            if next_token.tipo == T_OP and next_token.valor == '=':
                self.assignment()
            elif next_token.tipo == T_PARA:
                self.function_call()
        elif self.token_atual.tipo in [T_IF, T_ELSE, T_WHILE, T_FOR]:
            self.control_structure()
        elif self.token_atual.tipo == T_PRINT:
            self.parse_print()
        elif self.token_atual.tipo == T_RETURN:
            self.parse_return()
        else:
            self.erro("Instrução inesperada.")

    def variable_declaration(self):
        """
        Trata declarações de variáveis.
        """
        print("Parsing variable declaration...")
        var_type = self.token_atual.valor  # Tipo da variável (int, float, etc.)
        self.use(T_VAR_TYPE, "var")  # Consumir o tipo da variável
        var_name = self.token_atual.valor  # Nome da variável
        self.use(T_ID)  # Consumir o nome da variável
        self.use(T_DELIMITER, ";")  # Consumir o ponto e vírgula
        self.add_to_symbol_table(var_name)  # Adicionar a variável ao escopo atual
        self.ir.append(f"{var_type} {var_name};") # Adicionar a declaração de variável ao IR

    def assignment(self):
        """
        Trata atribuições de variáveis.
        """
        print("Parsing assignment...")
        var_name = self.token_atual.valor  # Nome da variável
        self.use(T_ID)  # Consumir o nome da variável
        self.use(T_OP, '=')  # Consumir o operador de atribuição

        # Verificar se a variável foi declarada
        if not self.is_declared_in_scope(var_name):
            raise Exception(f"Erro semantico. Variável {var_name} não foi declarada neste escopo.")

        # Processar a expressão à direita do operador de atribuição
        _, expr_str = self.expr()
        self.use(T_DELIMITER, ";")  # Consumir o ponto e vírgula
        self.ir.append(f"{var_name} = {expr_str};")  # Adicionar à representação intermediária
    
    def start(self):
        """
        start ::= { function_definition* main_block }
        """
        print("IR: ", self.ir)
        # Processa todas as definições de função
        while self.token_atual.tipo == T_FUNC:
            self.parse_function_definition()

        print("IR 22: ", self.ir)

        # Procura pelo token 'main'
        if self.token_atual.tipo != T_MAIN:
            raise Exception("Erro de sintaxe. Esperado: 'main' para o início do bloco principal.")

        # Processa o bloco main
        self.main_program()

        # Insere os includes no início do IR
        self.ir.insert(0, "#include <math.h>")
        self.ir.insert(0, "#include <stdio.h>")

    def main_program(self):
        """
        Parses the main program block.
        """
        self.use(T_MAIN)  # Consome o token 'main'
        self.use(T_BLOCK, "{")  # Espera '{' depois de 'main'

        self.ir.append("int main() {")

        self.instructions()

        self.ir.append("}")

        # Espera '}' no final do bloco main
        self.use(T_BLOCK, "}")
        #return

    def parse_function_definition(self):
        print("Parsing function definition...")
        self.use(T_FUNC)  # Consume 'func' token

        # Function name and parameters
        func_name = self.token_atual.valor
        self.use(T_ID)  # Consume function name
        self.use(T_PARA, "(")
        self.enter_scope()  # Entrando no escopo da função
        params = self.parse_parameters()
        self.use(T_PARA, ")")

        # Function body
        self.use(T_BLOCK, "{")
        func_body_ir = self.parse_instructions()
        self.use(T_BLOCK, "}")

        # Generate C code for the function definition
        self.exit_scope()  # Saindo do escopo da função
        print("IR: ", self.ir )
        function_ir = [f"void {func_name}({', '.join(['float ' + p for p in params])}) {{"] + func_body_ir + ["}"]
        self.ir.extend(function_ir)
        print("IR: ", self.ir)

    def parse_parameters(self):
        params = []
        while self.token_atual.tipo != T_PARA or (self.token_atual.tipo == T_PARA and self.token_atual.valor != ")"):
            if self.token_atual.tipo == T_ID:
                param_name = self.token_atual.valor
                self.add_to_symbol_table(param_name)  # Adiciona ao escopo atual
                params.append(param_name)
                self.use(T_ID)  # Consume the parameter name
            elif self.token_atual.tipo == T_COMMA:
                self.use(T_COMMA)  # Consume the comma
            else:
                self.erro("Expected an identifier or comma in function parameters.")
        return params


    def parse_instructions(self):
        """
        Parses a sequence of instructions until a closing block token is encountered.
        """
        self.enter_scope()  # Entrar em um novo escopo
        instructions = []
        while self.token_atual.tipo != T_BLOCK or (self.token_atual.tipo == T_BLOCK and self.token_atual.valor != "}"):
            self.instruction()
            instructions.extend(self.ir)  
            self.ir = []  
            self.proximo()
        self.exit_scope()  # Sair do escopo atual
        return instructions

    def function_call(self):
        func_name = self.token_atual.valor
        self.use(T_ID)
        self.use(T_PARA, "(")
        args = []

        while not (self.token_atual.tipo == T_PARA and self.token_atual.valor == ")"):
            if self.token_atual.tipo in [T_ID, T_INT, T_FLOAT]:
                args.append(self.token_atual.valor)
                self.use(self.token_atual.tipo)  # Consume the argument token
            elif self.token_atual.tipo == T_COMMA:
                self.use(T_COMMA)  # Consume the comma

        self.use(T_PARA, ")")
        args_str = ', '.join(args)
        self.ir.append(f"{func_name}({args_str});")


    def statement(self):
        """
        statement ::= <id> <op => expr | control_structure
        """
        print("Parsing statement...")
        if self.token_atual.tipo == T_IF:
            self.control_structure()
        elif self.token_atual.tipo == T_ID:
            # Check if the next token is an opening parenthesis to determine if it's a function call
            next_token = self.peek()
            if next_token.tipo == T_PARA: # and next_token.valor == "(": 
                self.function_call()  # Handle function calls
            else:
                # Handle variable assignment
                name = self.token_atual.valor
                self.use(T_ID)
                self.use(T_OP, '=')
                value, str_expr = self.expr()
                if name not in self.symbol_table:
                    raise Exception(f"Erro semantico. Simbolo {name} nao foi declarado.")
                self.symbol_table[name] = value
                self.ir.append(f"{name} = {str_expr};")
        elif self.token_atual.tipo == T_PRINT:
            self.parse_print() 
        elif self.token_atual.tipo == T_WHILE:
            self.parse_while()
        elif self.token_atual.tipo == T_FOR:
            self.parse_for()
        elif self.token_atual.tipo == T_RETURN:
            self.parse_return()
        else:
            self.erro("Instrução inesperada.")

    def parse_return(self):
        print("Parsing return statement...")
        self.use(T_RETURN)  # Consume 'return' token

        # Parse the return expression
        _, return_expr = self.expr()

        self.use(T_DELIMITER, ";")  # Consume the semicolon

        # Add the return statement to the intermediate representation (IR)
        self.ir.append(f"return {return_expr};")

    def peek(self):
        """
        Returns the next token without consuming it.
        """
        if self.pos + 1 < len(self.tokens):
            return self.tokens[self.pos + 1]
        else:
            return Token(T_EOF)

    def parse_while(self):
        print("Parsing while loop...")
        self.use(T_WHILE)
        self.use(T_PARA, "(")
        condition, condition_str = self.expr()  
        self.use(T_PARA, ")")
        self.use(T_BLOCK, "{")
        self.ir.append(f"while ({condition_str}) {{")  
        self.instructions()
        self.use(T_BLOCK, "}")
        self.ir.append("}")
        
    def parse_for(self):
        """
        Parses a for loop.
        for ( a -> b , c ) {
            print ( a )
        }
        """
        print("Parsing for loop...")
        self.use(T_FOR)
        self.use(T_PARA, "(")

        # Parse loop initialization
        start_variable = self.token_atual.valor
        self.use(T_ID)
        
        if self.token_atual.valor == '->':
            direction = 'increment'
            self.use(T_ARROW_UP)
        elif self.token_atual.valor == '<-':
            direction = 'decrement'
            self.use(T_ARROW_DOWN)

        end_variable = self.token_atual.valor
        self.use(T_ID)
        self.use(T_COMMA)

        # Parse step expression
        _, step_expression = self.expr()  # This should return a string representation of the step expression

        self.use(T_PARA, ")")

        # Generate C for loop code
        for_init = f"int {start_variable} = {start_variable};"
        for_cond = f"{start_variable} {'<=' if direction == 'increment' else '>='} {end_variable};"
        for_incr = f"{start_variable} {'+=' if direction == 'increment' else '-='} {step_expression}"
        self.ir.append(f"for ({for_init} {for_cond} {for_incr}) {{")

        # Parse loop body
        self.use(T_BLOCK, "{")
        self.instructions()
        self.use(T_BLOCK, "}")

        self.ir.append("}")

    def parse_print(self):
        """
        Parses a print statement.
        """
        print("Parsing print statement...")
        self.use(T_PRINT)
        self.use(T_PARA, "(")
        format_strings = []
        print_arguments = []

        while self.token_atual.tipo != T_PARA or (self.token_atual.tipo == T_PARA and self.token_atual.valor != ")"):
            if self.token_atual.tipo == T_STRING:
                # Strings literais
                format_strings.append("%s")
                print_arguments.append(self.token_atual.valor)
                self.use(T_STRING)
            elif self.token_atual.tipo == T_ID:
                var_name = self.token_atual.valor
                if not self.is_declared_in_scope(var_name):
                    raise Exception(f"Erro semântico. Variável {var_name} não foi declarada neste escopo.")

                format_type = "%d"  # Tipo padrão, pode mudar para "%f" se flutuante for mais comum
                if var_name in self.symbol_table and isinstance(self.symbol_table[var_name], float):
                    format_type = "%f"
                
                format_strings.append(format_type)
                print_arguments.append(var_name)
                self.use(T_ID)
            elif self.token_atual.tipo in [T_INT, T_FLOAT]:
                # Literais numéricos
                format_strings.append("%d" if self.token_atual.tipo == T_INT else "%f")
                print_arguments.append(self.token_atual.valor)
                self.use(self.token_atual.tipo)

            if self.token_atual.tipo == T_COMMA:
                self.use(T_COMMA)  # Consumir a vírgula

        self.use(T_PARA, ")")

        # Monta a string de formato e os argumentos para printf
        formatted_print = 'printf("' + ' '.join(format_strings) + '\\n", ' + ', '.join(print_arguments) + ');'
        self.ir.append(formatted_print)

    def control_structure(self):
        """
        control_structure ::= if ( expr ) { instructions } [ elif ( expr ) { instructions } ]* [ else { instructions } ]
        """
        print("Parsing control structure...")
        if self.token_atual.tipo == T_IF:
            self.use(T_IF)
            self.use(T_PARA, "(")
            condition, condition_str = self.expr()  # This should return a condition expressiondef
            self.use(T_PARA, ")")
            self.use(T_BLOCK, "{")
            self.enter_scope()
            self.ir.append(f"if ({condition_str}) {{")  # Properly format the if statement
            self.instructions()
            self.exit_scope()
            self.use(T_BLOCK, "}")
            self.ir.append("}")
        
        if self.token_atual.tipo == T_ELIF:
            self.use(T_ELIF)
            self.use(T_PARA, "(")
            condition, condition_str = self.expr()  # This should return a condition expression
            self.use(T_PARA, ")")
            self.use(T_BLOCK, "{")
            self.enter_scope()
            self.ir.append(f"else if ({condition_str}) {{")  
            self.instructions()
            self.exit_scope()
            self.use(T_BLOCK, "}")
            self.ir.append("}")
        
        if self.token_atual.tipo == T_ELSE:
            self.use(T_ELSE)
            self.use(T_BLOCK, "{")
            self.enter_scope()
            self.ir.append(f"else {{")
            self.instructions()
            self.exit_scope()
                    
    def compare_expr(self):
        """
        compare_expr ::= expr <op_comp> expr
        """
        left_value, left_str = self.arith_expr()
        op = self.token_atual.valor
        self.use(T_OP_COMP)
        right_value, right_str = self.arith_expr()
        return f"{left_str} {op} {right_str}"
            
        
    def expr(self):
        """
        expr ::= arith_expr | compare_expr
        """
        print("Parsing expression...")
        if self.token_atual.tipo in [T_INT, T_FLOAT, T_ID]:
            return self.arith_expr()
        elif self.token_atual.tipo == T_OP_COMP:
            return self.compare_expr()  
        else:
            self.erro("Invalid expression")

    def arith_expr(self):
        """
        arith_expr ::= term expr_e_line
        """
        print("Parsing arithmetic expression...")
        term_value, term_str = self.term()
        expr_line_value, expr_line_str = self.expr_e_line(term_value)
        return expr_line_value, f"{term_str} {expr_line_str}"

    def term(self):
        """
        term ::= factor expr_t_line
        """
        print("Parsing term...")
        factor_value, factor_str = self.factor()  # Parse the first factor
        term_line_value, term_line_str = self.expr_t_line(factor_value)  # Continue with products/divisions of factors
        return term_line_value, f"{factor_str} {term_line_str}"
    
    def factor(self):
        """
        factor ::= ( expr ) | <id> | <int> | <float>
        """
        if self.token_atual.tipo == T_PARA and self.token_atual.valor == "(":
            self.use(T_PARA, "(")
            _, expr_str = self.expr()
            self.use(T_PARA, ")")
            return _, f"({expr_str})"
        elif self.token_atual.tipo == T_ID:
            var_name = self.token_atual.valor
            self.use(T_ID)
            if not self.is_declared_in_scope(var_name):
                raise Exception(f"Erro semantico. Variável {var_name} não foi declarada neste escopo.")
            return self.symbol_table[var_name], var_name
        elif self.token_atual.tipo in [T_INT, T_FLOAT]:
            literal_value = float(self.token_atual.valor)
            self.use(T_INT if self.token_atual.tipo == T_INT else T_FLOAT)
            return literal_value, str(literal_value)
        else:
            self.erro("Expected a factor")
    
    def expr_t(self) -> int:
        """
        expr_t ::= expr_f expr_t_line
        """
        print("Parsing expression t...")
        r, s = self.expr_f()
        r2, s2 = self.expr_t_line(r)
        return r2, f"{s} {s2}"

    def expr_e_line(self, inherited_t: int):
        """
        expr_e_line ::= <op +> expr_t expr_e_line | 
                        <op -> expr_t expr_e_line | epsilon
        """
        print("Parsing expression e line...")
        if self.token_atual.tipo == T_OP:
            if self.token_atual.valor == "+":
                self.use(T_OP, "+")
                a, s = self.expr_t()
                res = a + inherited_t
                a2, s2 = self.expr_e_line(res)
                str_expr = f"+ {s} {s2}"
                return a2, str_expr
            elif self.token_atual.valor == "-":
                self.use(T_OP, "-")
                a, s = self.expr_t()
                res = inherited_t - a
                a2, s2 = self.expr_e_line(res)
                str_expr = f"- {s} {s2}"
                return a2, str_expr
            elif self.token_atual.valor == "*":
                self.use(T_OP, "*")
                a, s = self.expr_t()
                res = a * inherited_t
                a2, s2 = self.expr_e_line(res)
                str_expr = f"* {s} {s2}"
                return a2, str_expr
            elif self.token_atual.valor == "/":
                self.use(T_OP, "/")
                a, s = self.expr_t()
                if a == 0:
                    raise Exception("Erro semantico. Divisão por zero.")
                res = inherited_t / a
                a2, s2 = self.expr_e_line(res)
                str_expr = f"/ {s} {s2}"
                return a2, str_expr
        elif self.token_atual.valor in ["==", "!=", "<", ">", "<=", ">="]:
            teste = self.token_atual
            self.use(T_OP_COMP)
            a, s = self.expr_t()
            print("a: ", a, "s: ", s)   
            res = inherited_t
            a2, s2 = self.expr_e_line(res)
            str_expr = f"/ {s} {s2}"
            return a2, str_expr
            
        # Prod vazia
        return 0 + inherited_t, ""

    def expr_t_line(self, inherited_t: int):
        """
        expr_t_line ::= <op *> expr_f expr_t_line |
                        <op /> expr_f expr_t_line | epsilon
        """
        print("Parsing expression t line...")
        if self.token_atual.tipo == T_OP:
            if self.token_atual.valor == "*":
                self.use(T_OP, "*")
                a, s = self.expr_f()
                res = a * inherited_t
                a2, s2 = self.expr_t_line(res)
                str_expr = f"* {s} {s2}"
                return a2, str_expr
            elif self.token_atual.valor == "/":
                self.use(T_OP, "/")
                a, s = self.expr_f()
                if a == 0:
                    raise Exception("Erro semantico. Divisão por zero.")
                res = inherited_t / a
                a2, s2 = self.expr_t_line(res)
                str_expr = f"/ {s} {s2}"
                return a2, str_expr
        elif self.token_atual.tipo == T_OP_COMP:
            comp = self.token_atual
            self.use(T_OP_COMP)
            print("EEEEEEEEEEEEE")
            a, s = self.expr_f()
            res = inherited_t
            a2, s2 = self.expr_t_line(res)
            str_expr = f"{comp.valor} {s} {s2}"
            return a2, str_expr
        # Prod vazia
        return 1 * inherited_t, ""

    def expr_f(self):
        """
        expr_f ::= ( expr ) | <id> | <int> | <float> | sqrt ( expr ) | <int> ^ <int>
        """
        print("Parsing expression f...")
        str_expr = ""
        if self.token_atual.tipo == T_PARA:
            self.use(T_PARA, "(")
            res, s = self.expr()
            self.use(T_PARA, ")")
            str_expr = f"({s})"
        elif self.token_atual.tipo == T_ID:
            if self.token_atual.valor not in self.symbol_table:
                raise Exception(f"Erro Semantico, variavel {self.token_atual.valor} nao foi declarada")
            res = self.symbol_table[self.token_atual.valor]
            str_expr = self.token_atual.valor
            self.use(T_ID)
        elif self.token_atual.tipo == T_INT:
            # Converte o int para float antes de retornar o valor
            res = float(self.token_atual.valor)
            str_expr = str(self.token_atual.valor)
            self.use(T_INT)
        elif self.token_atual.tipo == T_FLOAT:
            str_expr = str(self.token_atual.valor)
            res = float(self.token_atual.valor)
            self.use(T_FLOAT)
        else:
            self.erro()

        return res, str_expr

##############################################################################

# test_token = afd_principal("print")
# print(test_token)

arquivo = open('codigo.x','r')
ln = 1

tokens = []

for l in arquivo.readlines():
    
    # analisador lexico
    
    l = l.replace('\n','') 

    for token in l.split():        
        try:
            tokens.append(afd_principal(token))
        except Exception as e:
            print(tokens)
            print(str(e) + " na posição %i da linha %i - %s" % (l.index(token), ln, token))
            raise StopExecution
    ln += 1

print([str(t) for t in tokens])
    
# analisador sintatico

parser = Parser(tokens)
parser.start()
code = parser.generate_ir()

with open("codigo.c", "w") as out_f:
    out_f.write(code)
# Out:
# ['<func func>', '<id teste>', '<parenthesis (>', '<id a>', '<parenthesis )>', '<block {>', '<print print>', '<parenthesis (>', '<id a>', '<parenthesis )>', '<delimiter ;>', '<block }>', '<main main>', '<block {>', '<var_type var>', '<id a>', '<delimiter ;>', '<var_type var>', '<id b>', '<delimiter ;>', '<id a>', '<op =>', '<int 2>', '<delimiter ;>', '<id b>', '<op =>', '<int 1>', '<delimiter ;>', '<print print>', '<parenthesis (>', '<id a>', '<parenthesis )>', '<delimiter ;>', '<id teste>', '<parenthesis (>', '<id a>', '<parenthesis )>', '<delimiter ;>', '<block }>']
# <func func>
# Token atual: <func func>, Posição: 0
# IR:  []
# Parsing function definition...
# <id teste>
# Token atual: <id teste>, Posição: 1
# <parenthesis (>
# Token atual: <parenthesis (>, Posição: 2
# <id a>
# Token atual: <id a>, Posição: 3
# <parenthesis )>
# Token atual: <parenthesis )>, Posição: 4
# <block {>
# Token atual: <block {>, Posição: 5
# <print print>
# Token atual: <print print>, Posição: 6
# Parsing instruction...
# Parsing print statement...
# <parenthesis (>
# Token atual: <parenthesis (>, Posição: 7
# <id a>
# Token atual: <id a>, Posição: 8
# <parenthesis )>
# Token atual: <parenthesis )>, Posição: 9
# <delimiter ;>
# Token atual: <delimiter ;>, Posição: 10
# <block }>
# Token atual: <block }>, Posição: 11
# <main main>
# Token atual: <main main>, Posição: 12
# IR:  []
# IR:  ['void teste(float a) {', 'printf("%d\\n", a);', '}']
# IR 22:  ['void teste(float a) {', 'printf("%d\\n", a);', '}']
# <block {>
# Token atual: <block {>, Posição: 13
# <var_type var>
# Token atual: <var_type var>, Posição: 14
# Parsing instructions...
# Parsing instruction...
# Parsing variable declaration...
# <id a>
# Token atual: <id a>, Posição: 15
# <delimiter ;>
# Token atual: <delimiter ;>, Posição: 16
# <var_type var>
# Token atual: <var_type var>, Posição: 17
# Parsing instruction...
# Parsing variable declaration...
# <id b>
# Token atual: <id b>, Posição: 18
# <delimiter ;>
# Token atual: <delimiter ;>, Posição: 19
# <id a>
# Token atual: <id a>, Posição: 20
# Parsing instruction...
# Parsing assignment...
# <op =>
# Token atual: <op =>, Posição: 21
# <int 2>
# Token atual: <int 2>, Posição: 22
# Parsing expression...
# Parsing arithmetic expression...
# Parsing term...
# <delimiter ;>
# Token atual: <delimiter ;>, Posição: 23
# Parsing expression t line...
# Parsing expression e line...
# <id b>
# Token atual: <id b>, Posição: 24
# Parsing instruction...
# Parsing assignment...
# <op =>
# Token atual: <op =>, Posição: 25
# <int 1>
# Token atual: <int 1>, Posição: 26
# Parsing expression...
# Parsing arithmetic expression...
# Parsing term...
# <delimiter ;>
# Token atual: <delimiter ;>, Posição: 27
# Parsing expression t line...
# Parsing expression e line...
# <print print>
# Token atual: <print print>, Posição: 28
# Parsing instruction...
# Parsing print statement...
# <parenthesis (>
# Token atual: <parenthesis (>, Posição: 29
# <id a>
# Token atual: <id a>, Posição: 30
# <parenthesis )>
# Token atual: <parenthesis )>, Posição: 31
# <delimiter ;>
# Token atual: <delimiter ;>, Posição: 32
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\gusta\Desktop\Lexer-compiler\03 - IR - completo.ipynb Cell 1 line 8
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=823'>824</a> # analisador sintatico
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=825'>826</a> parser = Parser(tokens)
# --> <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=826'>827</a> parser.start()
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=827'>828</a> code = parser.generate_ir()
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=829'>830</a> with open("codigo.c", "w") as out_f:
#
# c:\Users\gusta\Desktop\Lexer-compiler\03 - IR - completo.ipynb Cell 1 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=319'>320</a>     raise Exception("Erro de sintaxe. Esperado: 'main' para o início do bloco principal.")
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=321'>322</a> # Processa o bloco main
# --> <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=322'>323</a> self.main_program()
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=324'>325</a> # Insere os includes no início do IR
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=325'>326</a> self.ir.insert(0, "#include <math.h>")
#
# c:\Users\gusta\Desktop\Lexer-compiler\03 - IR - completo.ipynb Cell 1 line 3
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=339'>340</a> self.ir.append("}")
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=341'>342</a> # Espera '}' no final do bloco main
# --> <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=342'>343</a> self.use(T_BLOCK, "}")
#
# c:\Users\gusta\Desktop\Lexer-compiler\03 - IR - completo.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=234'>235</a> def use(self, tipo, valor=None):
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=235'>236</a>     if self.token_atual.tipo != tipo or (valor is not None and self.token_atual.valor != valor):
# --> <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=236'>237</a>         self.erro(expected=f"{tipo}{' ' + valor if valor else ''}")
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=237'>238</a>     else:
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=238'>239</a>         self.proximo()
#
# c:\Users\gusta\Desktop\Lexer-compiler\03 - IR - completo.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=229'>230</a> if message:
#     <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=230'>231</a>     error_message += f" {message}"
# --> <a href='vscode-notebook-cell:/c%3A/Users/gusta/Desktop/Lexer-compiler/03%20-%20IR%20-%20completo.ipynb#W0sZmlsZQ%3D%3D?line=231'>232</a> raise Exception(error_message)
#
# Exception: Erro de sintaxe. Esperado: block }, Encontrado: <delimiter ;>
